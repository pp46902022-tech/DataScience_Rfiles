# %% [markdown]
# <a href="https://colab.research.google.com/github/pp46902022-tech/DataScience_Rfiles/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("/content/Titanic_Table_Extract.xlsx")

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.groupby('Survived')['PassengerId'].count()
# Out:
# Survived
# 0    2
# 1    3
# Name: PassengerId, dtype: int64

# %%
sns.boxplot(x='Survived',y="Age",data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(x='Sex',y='Survived',data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
ax=plt.subplots(figsize=(8,6))
sns.boxplot(x='Sex',y='Age',hue='Survived',data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.barplot(x="Pclass",y="Survived",hue="Sex",data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
from scipy import stats

# %%
stats.norm.cdf(70,60,10)
# Out:
# np.float64(0.8413447460685429)

# %%
stats.norm.cdf(680,711,29)
# Out:
# np.float64(0.14254260383881612)

# %%
1-stats.norm.cdf(720,711,29)
# Out:
# np.float64(0.37814937265194704)

# %%
stats.norm.cdf(740,711,29)-stats.norm.cdf(680,711,29)
# Out:
# np.float64(0.6988021422297268)

# %%
from scipy import stats

# %%
stats.norm.cdf(740,711,29)

# %%
data.sex
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_745/2516639174.py in <cell line: 0>()
# ----> 1 data.sex
#
# NameError: name 'data' is not defined

# %%
data=pd.read_excel("/content/Titanic_Table_Extract.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_745/2741793875.py in <cell line: 0>()
# ----> 1 data=pd.read_excel("/content/Titanic_Table_Extract.xlsx")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("/content/Titanic_Table_Extract.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_745/2741793875.py in <cell line: 0>()
# ----> 1 data=pd.read_excel("/content/Titanic_Table_Extract.xlsx")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Titanic_Table_Extract.xlsx'

# %%
df=pd.read_excel("/content/Titanic_Table_Extract.xlsx")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Google Colab is available in VS Code!
# ![logo.webp](data:image/webp;base64,...)
#
# Try the new [Google Colab extension](https://marketplace.visualstudio.com/items?itemName=Google.colab) for Visual Studio Code. You can get up and running in just a few clicks:
#
# *  In VS Code, open the ***Extensions*** view and search for 'Google Colab' to install.
# *  Open the kernel selector by creating or opening any `.ipynb` notebook file in your local workspace and either running a cell or clicking the ***Select Kernel*** button in the top right.
# *  Click ***Colab*** and then select your desired runtime, sign in with your Google account, and you're all set!
#
# See more details in our [announcement blog here](https://developers.googleblog.com/google-colab-is-coming-to-vs-code).

# %%
df.Sex
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
df['Sex']
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
df[['Sex','Pclass']]
# Out:
#       Sex  Pclass
# 0    male       3
# 1  female       1
# 2  female       3
# 3  female       1
# 4    male       3

# %%
df[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
Beml=pd.read_excel("/content/BEML_data.xlsx")

# %%
Glaxo=pd.read_excel("/content/GLAXO_data.xlsx")

# %%
Beml
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                101651          1157.18
# 1                 59504           676.47
# 2                128908          1482.84
# 3                117871          1352.98
# 4                170063          1971.42

# %%
Glaxo
# Out:
#          Date     Open     High      Low  Last    Close  Total Trade Quantity  \
# 0  2010-01-04  1613.00  1629.10  1602.00  1629  1625.65                  9365
# 1  2010-01-05  1639.95  1639.95  1611.05  1620  1616.80                 38148
# 2  2010-01-06  1618.00  1644.00  1617.00  1639  1638.50                 36519
# 3  2010-01-07  1645.00  1654.00  1636.00  1648  1648.70                 12809
# 4  2010-01-08  1650.00  1650.00  1626.55  1640  1639.80                 28035
#
#    Turnover (Lacs)
# 0           151.74
# 1           622.58
# 2           595.09
# 3           211.00
# 4           459.11

# %%
Beml[['Date','Close']]
# Out:
#          Date    Close
# 0  2010-01-04  1135.60
# 1  2010-01-05  1134.60
# 2  2010-01-06  1139.60
# 3  2010-01-07  1144.15
# 4  2010-01-08  1144.05

# %%
Glaxo[['Date','Close']]
# Out:
#          Date    Close
# 0  2010-01-04  1625.65
# 1  2010-01-05  1616.80
# 2  2010-01-06  1638.50
# 3  2010-01-07  1648.70
# 4  2010-01-08  1639.80

# %%
Beml=Beml.set_index(pd.DatetimeIndex(Beml['Date']))
Glaxo=Glaxo.set_index(pd.DatetimeIndex(Glaxo['Date']))

# %%
Glaxo
# Out:
#                   Date     Open     High      Low  Last   Close  \
# Date
# 2010-01-05  2010-01-05  1639.95  1639.95  1611.05  1620  1616.8
# 2010-01-06  2010-01-06  1618.00  1644.00  1617.00  1639  1638.5
# 2010-01-07  2010-01-07  1645.00  1654.00  1636.00  1648  1648.7
# 2010-01-08  2010-01-08  1650.00  1650.00  1626.55  1640  1639.8
#
#             Total Trade Quantity  Turnover (Lacs)      gain
# Date
# 2010-01-05                 38148           622.58 -0.005444
# 2010-01-06                 36519           595.09  0.013422
# 2010-01-07                 12809           211.00  0.006225
# 2010-01-08                 28035           459.11 -0.005398

# %%
Beml
# Out:
#                   Date    Open     High      Low    Last    Close  \
# Date
# 2010-01-05  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2010-01-06  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 2010-01-07  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 2010-01-08  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#             Total Trade Quantity  Turnover (Lacs)      gain
# Date
# 2010-01-05                 59504           676.47 -0.000881
# 2010-01-06                128908          1482.84  0.004407
# 2010-01-07                117871          1352.98  0.003993
# 2010-01-08                170063          1971.42 -0.000087

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
plt.plot(Glaxo.Close)
plt.xlabel("time")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
plt.plot(Beml.Close)
plt.xlabel("time")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
Glaxo['gain']=Glaxo.Close.pct_change(periods=1)
Beml['gain']=Beml.Close.pct_change(periods=1)

# %%
Glaxo
# Out:
#                   Date     Open     High      Low  Last    Close  \
# Date
# 2010-01-04  2010-01-04  1613.00  1629.10  1602.00  1629  1625.65
# 2010-01-05  2010-01-05  1639.95  1639.95  1611.05  1620  1616.80
# 2010-01-06  2010-01-06  1618.00  1644.00  1617.00  1639  1638.50
# 2010-01-07  2010-01-07  1645.00  1654.00  1636.00  1648  1648.70
# 2010-01-08  2010-01-08  1650.00  1650.00  1626.55  1640  1639.80
#
#             Total Trade Quantity  Turnover (Lacs)      gain
# Date
# 2010-01-04                  9365           151.74       NaN
# 2010-01-05                 38148           622.58 -0.005444
# 2010-01-06                 36519           595.09  0.013422
# 2010-01-07                 12809           211.00  0.006225
# 2010-01-08                 28035           459.11 -0.005398

# %%
Beml
# Out:
#                   Date    Open     High      Low    Last    Close  \
# Date
# 2010-01-04  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 2010-01-05  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2010-01-06  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 2010-01-07  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 2010-01-08  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#             Total Trade Quantity  Turnover (Lacs)      gain
# Date
# 2010-01-04                101651          1157.18       NaN
# 2010-01-05                 59504           676.47 -0.000881
# 2010-01-06                128908          1482.84  0.004407
# 2010-01-07                117871          1352.98  0.003993
# 2010-01-08                170063          1971.42 -0.000087

# %%
Glaxo=Glaxo.dropna()

# %%
Beml=Beml.dropna()

# %%
plt.plot(Glaxo.gain)
plt.xlabel("Time")
plt.ylabel("Gain")
# Out:
# Text(0, 0.5, 'Gain')

# %%
plt.plot(Beml.gain)
plt.xlabel("Time")
plt.ylabel("Gain")
# Out:
# Text(0, 0.5, 'Gain')

# %%
sns.distplot(Glaxo.gain)
# Out:
# /tmp/ipykernel_745/2990239366.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Glaxo.gain)
# <Axes: xlabel='gain', ylabel='Density'>

# %%
sns.distplot(Beml.gain)
# Out:
# /tmp/ipykernel_745/1418031047.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Beml.gain)
# <Axes: xlabel='gain', ylabel='Density'>

# %%
print('Mean:',round(Glaxo.gain.mean(),4))
# Out:
# Mean: 0.0022

# %%
print('Mean:',round(Beml.gain.mean(),4))
# Out:
# Mean: 0.0019

# %%
print('Standard Deviation:',round(Beml.gain.std(),4))
# Out:
# Standard Deviation: 0.0027

# %%
print('Standard Deviation:',round(Glaxo.gain.std(),4))
# Out:
# Standard Deviation: 0.0093

# %% [markdown]
# ## Access popular AI models via Google-Colab-AI Without an API Key
# All users have access to most popular LLMs via the `google-colab-ai` Python library, and paid users have access to a wider selection of models. For more details, refer to the [getting started with google colab ai](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb).

# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")

# %% [markdown]
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %% [markdown]
# Colab now has AI features powered by [Gemini](https://gemini.google.com). The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning
#
# <div>
#
# These are a few of the notebooks related to Machine Learning, including Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Getting Started with cuML's accelerator mode](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cuml_sklearn_colab_demo.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [Train a CNN to classify handwritten digits on the MNIST dataset using Flax NNX API](https://colab.research.google.com/github/google/flax/blob/main/docs_nnx/mnist_tutorial.ipynb)
# - [Train a Vision Transformer (ViT) for image classification with JAX](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_Vision_transformer.ipynb)
# - [Text classification with a transformer language model using JAX](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_transformer_text_classification.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Train a miniGPT language model with JAX AI Stack](https://docs.jaxstack.ai/en/latest/JAX_for_LLM_pretraining.html)
# - [LoRA/QLoRA finetuning for LLM using Tunix](https://github.com/google/tunix/blob/main/examples/qlora_gemma.ipynb)
# - [Parameter-efficient fine-tuning of Gemma with LoRA and QLoRA](https://keras.io/examples/keras_recipes/parameter_efficient_finetuning_of_gemma_with_lora_and_qlora/)
# - [Loading Hugging Face Transformers Checkpoints](https://keras.io/keras_hub/guides/hugging_face_keras_integration/)
# - [8-bit Integer Quantization in Keras](https://keras.io/guides/int8_quantization_in_keras/)
# - [Float8 training and inference with a simple Transformer model](https://keras.io/examples/keras_recipes/float8_training_and_inference_with_transformer/)
# - [Pretraining a Transformer from scratch with KerasHub](https://keras.io/keras_hub/guides/transformer_pretraining/)
# - [Simple MNIST convnet](https://keras.io/examples/vision/mnist_convnet/)
# - [Image classification from scratch using Keras 3](https://keras.io/examples/vision/image_classification_from_scratch/)
# - [Image Classification with KerasHub](https://keras.io/keras_hub/guides/classification_with_keras_hub/)

# %%
1+1
# Out:
# 2

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/Copy of Structured data.xlsx")

# %%
df.head()
# Out:
#   Example of Unstructrured Data  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                           NaN         NaN         NaN         NaN
# 1                  Country Name      1999.0      2000.0      2001.0
# 2                        Canada  30499200.0  30769700.0  31081900.0
# 3                       Germany  82100243.0  82211508.0  82349925.0
# 4                        France  60496715.0  60912498.0  61357431.0
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1      2002.0      2003.0      2004.0      2005.0      2006.0      2007.0
# 2  31362000.0  31676000.0  31995000.0  32312000.0  32570505.0  32887928.0
# 3  82488495.0  82534176.0  82516260.0  82469422.0  82376451.0  82266372.0
# 4  61805267.0  62244884.0  62704897.0  63179356.0  63621376.0  64016229.0
#
#    ...  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0  ...          NaN          NaN          NaN          NaN          NaN
# 1  ...       2009.0       2010.0       2011.0       2012.0       2013.0
# 2  ...   33628571.0   34005274.0   34342780.0   34754312.0   35158304.0
# 3  ...   81902307.0   81776930.0   81797673.0   80425823.0   80645605.0
# 4  ...   64707044.0   65027512.0   65342776.0   65639975.0   65925498.0
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19 Unnamed: 20
# 0          NaN          NaN          NaN          NaN         NaN
# 1       2014.0       2015.0       2016.0        Total          %
# 2   35540419.0   35540419.0   35540419.0    596910504         NaN
# 3   80889505.0   80889505.0   80889505.0   1472639802         NaN
# 4   66206930.0   66206930.0   66206930.0   1149977238         NaN
#
# [5 rows x 21 columns]

# %%
df=pd.read_excel("/content/Copy of Structured data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1584/2373365607.py in <cell line: 0>()
# ----> 1 df=pd.read_excel("/content/Copy of Structured data.xlsx")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/Copy of Structured data.xlsx")

# %%
df.head()
# Out:
#   Example of Unstructrured Data  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                           NaN         NaN         NaN         NaN
# 1                  Country Name      1999.0      2000.0      2001.0
# 2                        Canada  30499200.0  30769700.0  31081900.0
# 3                       Germany  82100243.0  82211508.0  82349925.0
# 4                        France  60496715.0  60912498.0  61357431.0
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1      2002.0      2003.0      2004.0      2005.0      2006.0      2007.0
# 2  31362000.0  31676000.0  31995000.0  32312000.0  32570505.0  32887928.0
# 3  82488495.0  82534176.0  82516260.0  82469422.0  82376451.0  82266372.0
# 4  61805267.0  62244884.0  62704897.0  63179356.0  63621376.0  64016229.0
#
#    ...  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0  ...          NaN          NaN          NaN          NaN          NaN
# 1  ...       2009.0       2010.0       2011.0       2012.0       2013.0
# 2  ...   33628571.0   34005274.0   34342780.0   34754312.0   35158304.0
# 3  ...   81902307.0   81776930.0   81797673.0   80425823.0   80645605.0
# 4  ...   64707044.0   65027512.0   65342776.0   65639975.0   65925498.0
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19 Unnamed: 20
# 0          NaN          NaN          NaN          NaN         NaN
# 1       2014.0       2015.0       2016.0        Total          %
# 2   35540419.0   35540419.0   35540419.0    596910504         NaN
# 3   80889505.0   80889505.0   80889505.0   1472639802         NaN
# 4   66206930.0   66206930.0   66206930.0   1149977238         NaN
#
# [5 rows x 21 columns]

# %%
df.head(10)
# Out:
#   Example of Unstructrured Data   Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 0                           NaN          NaN          NaN          NaN
# 1                  Country Name       1999.0       2000.0       2001.0
# 2                        Canada   30499200.0   30769700.0   31081900.0
# 3                       Germany   82100243.0   82211508.0   82349925.0
# 4                        France   60496715.0   60912498.0   61357431.0
# 5                        Mexico  101266570.0  102808590.0  104239563.0
# 6                           USA  279040000.0  282162411.0  284968955.0
# 7                         Total  553402728.0  558864707.0  563997774.0
# 8                             %          NaN          NaN          NaN
#
#     Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1       2002.0       2003.0       2004.0       2005.0       2006.0
# 2   31362000.0   31676000.0   31995000.0   32312000.0   32570505.0
# 3   82488495.0   82534176.0   82516260.0   82469422.0   82376451.0
# 4   61805267.0   62244884.0   62704897.0   63179356.0   63621376.0
# 5  105578297.0  106888418.0  108257822.0  109747906.0  111382857.0
# 6  287625193.0  290107933.0  292805298.0  295516599.0  298379912.0
# 7  568859252.0  573451411.0  578279277.0  583225283.0  588331101.0
# 8          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 9  ...  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0          NaN  ...          NaN          NaN          NaN          NaN
# 1       2007.0  ...       2009.0       2010.0       2011.0       2012.0
# 2   32887928.0  ...   33628571.0   34005274.0   34342780.0   34754312.0
# 3   82266372.0  ...   81902307.0   81776930.0   81797673.0   80425823.0
# 4   64016229.0  ...   64707044.0   65027512.0   65342776.0   65639975.0
# 5  113139374.0  ...  116815612.0  118617542.0  120365271.0  122070963.0
# 6  301231207.0  ...  306771529.0  309347057.0  311721632.0  314112078.0
# 7  593541110.0  ...  603825063.0  608774315.0  613570132.0  617003151.0
# 8          NaN  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19 Unnamed: 20
# 0          NaN          NaN          NaN          NaN          NaN         NaN
# 1       2013.0       2014.0       2015.0       2016.0        Total          %
# 2   35158304.0   35540419.0   35540419.0   35540419.0    596910504         NaN
# 3   80645605.0   80889505.0   80889505.0   80889505.0   1472639802         NaN
# 4   65925498.0   66206930.0   66206930.0   66206930.0   1149977238         NaN
# 5  123740109.0  125385833.0  125385833.0  125385833.0   2056049214         NaN
# 6  316497531.0  318857056.0  318857056.0  318857056.0   5430952469         NaN
# 7  621967047.0  626879743.0  626879743.0  626879743.0  10706529227         NaN
# 8          NaN          NaN          NaN          NaN          NaN         NaN
#
# [9 rows x 21 columns]

# %%
df.dtypes
# Out:
# Example of Unstructrured Data     object
# Unnamed: 1                       float64
# Unnamed: 2                       float64
# Unnamed: 3                       float64
# Unnamed: 4                       float64
# Unnamed: 5                       float64
# Unnamed: 6                       float64
# Unnamed: 7                       float64
# Unnamed: 8                       float64
# Unnamed: 9                       float64
# Unnamed: 10                      float64
# Unnamed: 11                      float64
# Unnamed: 12                      float64
# Unnamed: 13                      float64
# Unnamed: 14                      float64
# Unnamed: 15                      float64
# Unnamed: 16                      float64
# Unnamed: 17                      float64
# Unnamed: 18                      float64
# Unnamed: 19                       object
# Unnamed: 20                       object
# dtype: object

# %%
df.size
# Out:
# 189

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=9, step=1),
#  Index(['Example of Unstructrured Data', 'Unnamed: 1', 'Unnamed: 2',
#         'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#         'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#         'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#         'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#        dtype='object')]

# %%
df.shape
# Out:
# (9, 21)

# %%
df.columns
# Out:
# Index(['Example of Unstructrured Data', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
df.values
# Out:
# array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan],
#        ['Country Name', 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0,
#         2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0,
#         2013.0, 2014.0, 2015.0, 2016.0, 'Total', '% '],
#        ['Canada', 30499200.0, 30769700.0, 31081900.0, 31362000.0,
#         31676000.0, 31995000.0, 32312000.0, 32570505.0, 32887928.0,
#         33245773.0, 33628571.0, 34005274.0, 34342780.0, 34754312.0,
#         35158304.0, 35540419.0, 35540419.0, 35540419.0, 596910504, nan],
#        ['Germany', 82100243.0, 82211508.0, 82349925.0, 82488495.0,
#         82534176.0, 82516260.0, 82469422.0, 82376451.0, 82266372.0,
#         82110097.0, 81902307.0, 81776930.0, 81797673.0, 80425823.0,
#         80645605.0, 80889505.0, 80889505.0, 80889505.0, 1472639802, nan],
#        ['France', 60496715.0, 60912498.0, 61357431.0, 61805267.0,
#         62244884.0, 62704897.0, 63179356.0, 63621376.0, 64016229.0,
#         64374990.0, 64707044.0, 65027512.0, 65342776.0, 65639975.0,
#         65925498.0, 66206930.0, 66206930.0, 66206930.0, 1149977238, nan],
#        ['Mexico', 101266570.0, 102808590.0, 104239563.0, 105578297.0,
#         106888418.0, 108257822.0, 109747906.0, 111382857.0, 113139374.0,
#         114972821.0, 116815612.0, 118617542.0, 120365271.0, 122070963.0,
#         123740109.0, 125385833.0, 125385833.0, 125385833.0, 2056049214,
#         nan],
#        ['USA', 279040000.0, 282162411.0, 284968955.0, 287625193.0,
#         290107933.0, 292805298.0, 295516599.0, 298379912.0, 301231207.0,
#         304093966.0, 306771529.0, 309347057.0, 311721632.0, 314112078.0,
#         316497531.0, 318857056.0, 318857056.0, 318857056.0, 5430952469,
#         nan],
#        ['Total', 553402728.0, 558864707.0, 563997774.0, 568859252.0,
#         573451411.0, 578279277.0, 583225283.0, 588331101.0, 593541110.0,
#         598797647.0, 603825063.0, 608774315.0, 613570132.0, 617003151.0,
#         621967047.0, 626879743.0, 626879743.0, 626879743.0, 10706529227,
#         nan],
#        ['%', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan]], dtype=object)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 189

# %%
df.columns.size
# Out:
# 21

# %%
df.columns
# Out:
# Index(['Example of Unstructrured Data', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')
# Index(['Example of Unstructrured Data', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
df.shape
# Out:
# (9, 21)

# %%
df.shape[1]
# Out:
# 21

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/Excel sal data.xlsx")

# %%
df.head()
# Out:
#    Empcode First Name    Last Name     Dept Region     Branch   Hiredate  \
# 0       38     Chitra     Pednekar  Finance  north    Aligarh 1982-10-01
# 1        1       Raja  Raymondekar    Sales  north  Ferozepur 1977-01-01
# 2       75      Suraj      Saksena    Admin   east   Calcutta 1988-10-25
# 3       81       Tara        Phule      CCD  south    chennai 1988-10-31
# 4       42      Pooja      Gokhale      R&D   east   Calcutta 1991-09-29
#
#    Basic Salary  Basic Salary- Color bars  Basic Salary- icon set
# 0          8900                     890.0                    8900
# 1          9000                     900.0                    9000
# 2         17487                    1748.7                   17487
# 3         17872                    1787.2                   17872
# 4         20095                    2009.5                   20095

# %%
df.size
# Out:
# 1000

# %%
df.shape
# Out:
# (100, 10)

# %%
df.shape[1]
# Out:
# 10

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['Empcode', 'First Name', 'Last Name', 'Dept', 'Region', 'Branch',
#         'Hiredate', 'Basic Salary', 'Basic Salary- Color bars',
#         'Basic Salary- icon set'],
#        dtype='object')]

# %%
df.columns
# Out:
# Index(['Empcode', 'First Name', 'Last Name', 'Dept', 'Region', 'Branch',
#        'Hiredate', 'Basic Salary', 'Basic Salary- Color bars',
#        'Basic Salary- icon set'],
#       dtype='object')

# %%
df.values
# Out:
# array([[38, 'Chitra', 'Pednekar', 'Finance', 'north', 'Aligarh',
#         Timestamp('1982-10-01 00:00:00'), 8900, 890.0, 8900],
#        [1, 'Raja', 'Raymondekar', 'Sales', 'north', 'Ferozepur',
#         Timestamp('1977-01-01 00:00:00'), 9000, 900.0, 9000],
#        [75, 'Suraj', 'Saksena', 'Admin', 'east', 'Calcutta',
#         Timestamp('1988-10-25 00:00:00'), 17487, 1748.7, 17487],
#        [81, 'Tara', 'Phule', 'CCD', 'south', 'chennai',
#         Timestamp('1988-10-31 00:00:00'), 17872, 1787.2, 17872],
#        [42, 'Pooja', 'Gokhale', 'R&D', 'east', 'Calcutta',
#         Timestamp('1991-09-29 00:00:00'), 20095, 2009.5, 20095],
#        [8, 'Neena', 'Mukherjee', 'R&D', 'north', 'Agra',
#         Timestamp('1989-09-04 00:00:00'), 20739, 2073.9, 20739],
#        [80, 'Dayanand', 'Gandhi', 'Mktg', 'north', 'Ferozepur',
#         Timestamp('1988-10-30 00:00:00'), 21207, 2120.7000000000003,
#         21207],
#        [18, 'Aakash', 'Dixit', 'Admin', 'west', 'Nasik',
#         Timestamp('1983-03-01 00:00:00'), 21682, 2168.2000000000003,
#         21682],
#        [88, 'Vinit', 'Shrivastava', 'Mktg', 'west', 'Pune',
#         Timestamp('1997-12-30 00:00:00'), 22139, 2213.9, 22139],
#        [15, 'K. Sita', 'Narayanan', 'Personnel', 'north', 'Jammu',
#         Timestamp('1984-12-13 00:00:00'), 23671, 2367.1, 23671],
#        [56, 'Kajal', 'Joglekar', 'Sales', 'west', 'Nagpur',
#         Timestamp('1992-10-01 00:00:00'), 23703, 2370.3, 23703],
#        [62, 'Asha', 'Trivedi', 'Sales', 'north', 'Kanpur',
#         Timestamp('1987-11-26 00:00:00'), 24095, 2409.5, 24095],
#        [55, 'Lalita', 'Rao', 'CCD', 'east', 'Guwahati',
#         Timestamp('1986-11-01 00:00:00'), 26940, 2694.0, 26940],
#        [31, 'Giriraj', 'Gupta', 'R&D', 'north', 'Agra',
#         Timestamp('1982-10-01 00:00:00'), 27206, 2720.6000000000004,
#         27206],
#        [20, 'Farhan', 'Sadiq', 'Mktg', 'north', 'Jaipur',
#         Timestamp('1999-06-05 00:00:00'), 28084, 2808.4, 28084],
#        [36, 'Pooja', 'Khetan', 'Personnel', 'west', 'Surat',
#         Timestamp('1994-09-03 00:00:00'), 28104, 2810.4, 28104],
#        [97, 'Pushpa', 'Raut', 'R&D', 'south', 'Trivanadrum',
#         Timestamp('1989-04-10 00:00:00'), 28361, 2836.1000000000004,
#         28361],
#        [64, 'Veena', 'Patil', 'Personnel', 'south', 'Hydrabad',
#         Timestamp('1988-10-25 00:00:00'), 28632, 2863.2000000000003,
#         28632],
#        [85, 'Ruby', 'Joseph', 'R&D', 'north', 'Agra',
#         Timestamp('1998-01-14 00:00:00'), 30215, 3021.5, 30215],
#        [40, 'Richa', 'Raje', 'Sales', 'south', 'Manglore',
#         Timestamp('1991-09-29 00:00:00'), 31550, 3155.0, 31550],
#        [99, 'Indu', 'Shah', 'Finance', 'west', 'Mumbai',
#         Timestamp('1997-12-30 00:00:00'), 34194, 3419.4, 34194],
#        [49, 'Rakesh', 'Kumar', 'CCD', 'south', 'cochin',
#         Timestamp('1988-10-19 00:00:00'), 35707, 3570.7000000000003,
#         35707],
#        [47, 'Vicky', 'Joshi', 'Admin', 'north', 'Kanpur',
#         Timestamp('1988-02-07 00:00:00'), 39307, 3930.7000000000003,
#         39307],
#        [11, 'Sujay', 'Madhrani', 'Finance', 'west', 'Pune',
#         Timestamp('1985-12-21 00:00:00'), 40192, 4019.2000000000003,
#         40192],
#        [73, 'Laveena', 'Shenoy', 'CCD', 'north', 'Jaipur',
#         Timestamp('1988-10-23 00:00:00'), 40267, 4026.7000000000003,
#         40267],
#        [27, 'Rishi', 'Malik', 'Sales', 'south', 'Banglore',
#         Timestamp('1992-07-02 00:00:00'), 40355, 4035.5, 40355],
#        [39, 'Sheetal', 'Dodhia', 'Finance', 'north', 'delhi',
#         Timestamp('1982-10-01 00:00:00'), 40395, 4039.5, 40395],
#        [72, 'Yamini', 'Gupta', 'R&D', 'south', 'Mysore',
#         Timestamp('1988-10-22 00:00:00'), 40462, 4046.2000000000003,
#         40462],
#        [76, 'Nayeem', 'Khan', 'CCD', 'west', 'Panji',
#         Timestamp('1988-10-26 00:00:00'), 40571, 4057.1000000000004,
#         40571],
#        [21, 'Satinder Kaur', 'Sasan', 'Mktg', 'east', 'Patna',
#         Timestamp('1999-06-06 00:00:00'), 40624, 4062.4, 40624],
#        [37, 'Shilpa', 'Parikh', 'Finance', 'south', 'Mysore',
#         Timestamp('1982-10-01 00:00:00'), 40696, 4069.6000000000004,
#         40696],
#        [68, 'Mandakini', 'Desai', 'Sales', 'north', 'delhi',
#         Timestamp('1995-12-01 00:00:00'), 40787, 4078.7000000000003,
#         40787],
#        [83, 'Kunal', 'Shah', 'CCD', 'north', 'Aligarh',
#         Timestamp('1999-03-02 00:00:00'), 41996, 4199.6, 41996],
#        [90, 'Priyanka', 'Mehta', 'R&D', 'north', 'Jaipur',
#         Timestamp('1980-01-06 00:00:00'), 42070, 4207.0, 42070],
#        [93, 'Harsha', 'Trivedi', 'Sales', 'south', 'Banglore',
#         Timestamp('1989-04-06 00:00:00'), 42730, 4273.0, 42730],
#        [5, 'Seema', 'Ranganathan', 'R&D', 'north', 'Kanpur',
#         Timestamp('1989-09-04 00:00:00'), 42770, 4277.0, 42770],
#        [30, 'Aalam', 'Qureshi', 'Personnel', 'east', 'Patna',
#         Timestamp('1988-10-19 00:00:00'), 43065, 4306.5, 43065],
#        [33, 'Tapan', 'Ghoshal', 'CCD', 'north', 'Ambala',
#         Timestamp('1997-07-07 00:00:00'), 43524, 4352.400000000001,
#         43524],
#        [86, 'Sonia', 'Sasan', 'CCD', 'north', 'Jammu',
#         Timestamp('1998-01-15 00:00:00'), 43840, 4384.0, 43840],
#        [12, 'Shilpa', 'Lele', 'Admin', 'north', 'Jammu',
#         Timestamp('1983-03-01 00:00:00'), 44018, 4401.8, 44018],
#        [22, 'Suchita', 'Panchal', 'Mktg', 'west', 'Nasik',
#         Timestamp('1999-06-07 00:00:00'), 44198, 4419.8, 44198],
#        [48, 'Neha', 'Joshi', 'CCD', 'west', 'Baroda',
#         Timestamp('1988-10-19 00:00:00'), 44731, 4473.1, 44731],
#        [69, 'Pravin', 'Joshi', 'Personnel', 'north', 'delhi',
#         Timestamp('1995-03-03 00:00:00'), 45991, 4599.1, 45991],
#        [28, 'Mala', 'Bhaduri', 'R&D', 'west', 'Mumbai',
#         Timestamp('1995-03-19 00:00:00'), 46025, 4602.5, 46025],
#        [65, 'Timsi', 'Desai', 'CCD', 'east', 'Calcutta',
#         Timestamp('1988-10-26 00:00:00'), 46669, 4666.900000000001,
#         46669],
#        [79, 'Sagar', 'Bidkar', 'Mktg', 'north', 'Delhi',
#         Timestamp('1988-10-29 00:00:00'), 46686, 4668.6, 46686],
#        [57, 'Katti', 'Surti', 'Sales', 'south', 'chennai',
#         Timestamp('1993-05-09 00:00:00'), 47117, 4711.7, 47117],
#        [4, 'Beena', 'Mavadia', 'Mktg', 'north', 'Delhi',
#         Timestamp('1979-11-24 00:00:00'), 47211, 4721.1, 47211],
#        [60, 'Geeta', 'Darekar', 'Mktg', 'south', 'Trivanadrum',
#         Timestamp('1987-11-24 00:00:00'), 48806, 4880.6, 48806],
#        [98, 'Chetan', 'Dalvi', 'CCD', 'north', 'Delhi',
#         Timestamp('1989-04-11 00:00:00'), 49435, 4943.5, 49435],
#        [34, 'Zarina', 'Vora', 'CCD', 'north', 'Lucknow',
#         Timestamp('1991-09-29 00:00:00'), 49755, 4975.5, 49755],
#        [66, 'Parul', 'Shah', 'Personnel', 'north', 'Agra',
#         Timestamp('1988-10-27 00:00:00'), 49928, 4992.8, 49928],
#        [44, 'Shaheen', 'Khan', 'Personnel', 'east', 'Cuttack',
#         Timestamp('1990-11-17 00:00:00'), 50040, 5004.0, 50040],
#        [92, 'Payal', 'Singhani', 'Mktg', 'east', 'Gangtok',
#         Timestamp('1989-04-05 00:00:00'), 50639, 5063.900000000001,
#         50639],
#        [51, 'Mario', 'Fernandes', 'Sales', 'north', 'Jammu',
#         Timestamp('1988-10-20 00:00:00'), 51234, 5123.400000000001,
#         51234],
#        [19, 'Parvati', 'Khanna', 'Mktg', 'north', 'Mathura',
#         Timestamp('1986-08-13 00:00:00'), 52953, 5295.3, 52953],
#        [41, 'Kirtikar', 'Sardesai', 'Admin', 'east', 'Darjeeling',
#         Timestamp('1997-06-14 00:00:00'), 53369, 5336.900000000001,
#         53369],
#        [32, 'Ankur', 'Joshi', 'CCD', 'south', 'Manglore',
#         Timestamp('1982-10-01 00:00:00'), 53567, 5356.700000000001,
#         53567],
#        [96, 'Beena', 'Sharma', 'R&D', 'west', 'Nagpur',
#         Timestamp('1989-04-09 00:00:00'), 53648, 5364.8, 53648],
#        [59, 'Disha', 'Parmar', 'Admin', 'south', 'Banglore',
#         Timestamp('1987-01-14 00:00:00'), 53922, 5392.200000000001,
#         53922],
#        [84, 'Pinky', 'Robert', 'R&D', 'east', 'Calcutta',
#         Timestamp('1999-03-03 00:00:00'), 54124, 5412.400000000001,
#         54124],
#        [2, 'Suman', 'Shinde', 'Sales', 'east', 'Cuttack',
#         Timestamp('1977-01-01 00:00:00'), 54154, 5415.400000000001,
#         54154],
#        [77, 'Drishti', 'Shah', 'R&D', 'north', 'Delhi',
#         Timestamp('1988-10-27 00:00:00'), 54577, 5457.700000000001,
#         54577],
#        [26, 'Bharat', 'Shetty', 'Sales', 'east', 'Cuttack',
#         Timestamp('1982-10-01 00:00:00'), 54770, 5477.0, 54770],
#        [43, 'Piyush', 'Surti', 'Personnel', 'west', 'Mumbai',
#         Timestamp('1988-10-19 00:00:00'), 55308, 5530.8, 55308],
#        [100, 'Rupesh', 'Sawant', 'Finance', 'south', 'Hydrabad',
#         Timestamp('1999-02-02 00:00:00'), 56237, 5623.700000000001,
#         56237],
#        [94, 'Radhika', 'Kulkarni', 'Mktg', 'west', 'Surat',
#         Timestamp('1989-04-07 00:00:00'), 56665, 5666.5, 56665],
#        [74, 'Nita', 'Pandhya', 'Sales', 'east', 'Darjeeling',
#         Timestamp('1988-10-24 00:00:00'), 57609, 5760.900000000001,
#         57609],
#        [7, 'Deepak', 'Jain', 'Personnel', 'west', 'Pune',
#         Timestamp('1990-08-17 00:00:00'), 57715, 5771.5, 57715],
#        [63, 'Waheda', 'Sheikh', 'R&D', 'north', 'Jammu',
#         Timestamp('1988-10-24 00:00:00'), 57970, 5797.0, 57970],
#        [25, 'Jasbinder', 'Khurana', 'R&D', 'south', 'Manglore',
#         Timestamp('1999-04-24 00:00:00'), 58445, 5844.5, 58445],
#        [50, 'Ruheal', 'Baig', 'Personnel', 'west', 'Baroda',
#         Timestamp('1988-10-19 00:00:00'), 58459, 5845.900000000001,
#         58459],
#        [13, 'Meera', 'Lalwani', 'Finance', 'east', 'Calcutta',
#         Timestamp('1984-12-11 00:00:00'), 59387, 5938.700000000001,
#         59387],
#        [53, 'Mehul', 'Sheth', 'CCD', 'west', 'Nagpur',
#         Timestamp('1995-12-01 00:00:00'), 60861, 6086.1, 60861],
#        [17, 'Aalok', 'Trivedi', 'Admin', 'east', 'Cuttack',
#         Timestamp('1983-03-01 00:00:00'), 61747, 6174.700000000001,
#         61747],
#        [6, 'Julie', "D'Souza", 'R&D', 'north', 'Mathura',
#         Timestamp('1988-09-04 00:00:00'), 61830, 6183.0, 61830],
#        [24, 'Pooja', 'Nimkar', 'Sales', 'west', 'Nasik',
#         Timestamp('1980-05-21 00:00:00'), 62617, 6261.700000000001,
#         62617],
#        [95, 'Kabir', 'Vora', 'Mktg', 'south', 'Banglore',
#         Timestamp('1989-04-08 00:00:00'), 62641, 6264.1, 62641],
#        [70, 'Reeta', 'Naik', 'Mktg', 'east', 'Calcutta',
#         Timestamp('1995-03-04 00:00:00'), 62648, 6264.8, 62648],
#        [29, 'Hajra', 'Hoonjan', 'Admin', 'north', 'Jaipur',
#         Timestamp('1996-05-04 00:00:00'), 62731, 6273.1, 62731],
#        [91, 'Niki', 'Digaria', 'Sales', 'east', 'Calcutta',
#         Timestamp('1979-11-13 00:00:00'), 63992, 6399.200000000001,
#         63992],
#        [23, 'Shazia', 'Sheikh', 'Mktg', 'west', 'Pune',
#         Timestamp('1999-06-08 00:00:00'), 64224, 6422.400000000001,
#         64224],
#        [45, 'Kinnari', 'Mehta', 'R&D', 'north', 'Ferozepur',
#         Timestamp('1997-07-07 00:00:00'), 64575, 6457.5, 64575],
#        [16, 'Priya', 'Shirodkar', 'Personnel', 'north', 'Jaipur',
#         Timestamp('1984-12-14 00:00:00'), 64941, 6494.1, 64941],
#        [82, 'Kalpana', 'Shirishkar', 'R&D', 'east', 'Cuttack',
#         Timestamp('1988-11-01 00:00:00'), 65301, 6530.1, 65301],
#        [67, 'Uday', 'Naik', 'Personnel', 'north', 'Lucknow',
#         Timestamp('1988-10-28 00:00:00'), 65625, 6562.5, 65625],
#        [61, 'Anuradha', 'Zha', 'Admin', 'north', 'Agra',
#         Timestamp('1987-11-25 00:00:00'), 65720, 6572.0, 65720],
#        [89, 'Tejal', 'Patel', 'Sales', 'north', 'Aligarh',
#         Timestamp('1979-02-21 00:00:00'), 65958, 6595.8, 65958],
#        [10, 'Andre', 'Fernendes', 'Mktg', 'east', 'Darjeeling',
#         Timestamp('1977-07-20 00:00:00'), 66346, 6634.6, 66346],
#        [71, 'Surendra', 'Godse', 'R&D', 'west', 'Panji',
#         Timestamp('1995-03-05 00:00:00'), 66400, 6640.0, 66400],
#        [52, 'Heena', 'Godbole', 'CCD', 'north', 'Lucknow',
#         Timestamp('1988-10-21 00:00:00'), 71306, 7130.6, 71306],
#        [9, 'Pankaj', 'Sutradhar', 'Sales', 'north', 'Ambala',
#         Timestamp('1999-12-12 00:00:00'), 72674, 7267.400000000001,
#         72674],
#        [46, 'Jeena', 'Baig', 'Sales', 'north', 'Lucknow',
#         Timestamp('1991-09-29 00:00:00'), 75234, 7523.400000000001,
#         75234],
#        [58, 'Maya', 'Panchal', 'Mktg', 'north', 'Agra',
#         Timestamp('1990-11-05 00:00:00'), 75768, 7576.8, 75768],
#        [35, 'Arun', 'Joshi', 'Mktg', 'south', 'Manglore',
#         Timestamp('1992-05-05 00:00:00'), 78696, 7869.6, 78696],
#        [3, 'Kuldeep', 'Sharma', 'Admin', 'south', 'Hydrabad',
#         Timestamp('1999-03-01 00:00:00'), 81527, 8152.700000000001,
#         81527],
#        [87, 'Jignesh', 'Tripathi', 'Mktg', 'south', 'Hydrabad',
#         Timestamp('1998-01-16 00:00:00'), 83428, 8342.800000000001,
#         83428],
#        [54, 'Vishal', 'Virsinghani', 'CCD', 'east', 'Gangtok',
#         Timestamp('1995-03-03 00:00:00'), 84724, 8472.4, 84724],
#        [78, 'Deep', 'Chhaya', 'Sales', 'west', 'Mumbai',
#         Timestamp('1988-10-28 00:00:00'), 85860, 8586.0, 85860],
#        [14, 'Sheetal', 'Desai', 'Director', 'south', 'cochin',
#         Timestamp('1984-12-12 00:00:00'), 93317, 9331.7, 93317]],
#       dtype=object)

# %%
df.describe()
# Out:
#           Empcode             Hiredate  Basic Salary  \
# count  100.000000                  100    100.000000
# mean    50.500000  1989-12-15 15:21:36  48892.870000
# min      1.000000  1977-01-01 00:00:00   8900.000000
# 25%     25.750000  1987-09-06 12:00:00  40333.000000
# 50%     50.500000  1988-10-29 12:00:00  49595.000000
# 75%     75.250000  1995-03-03 00:00:00  61767.750000
# max    100.000000  1999-12-12 00:00:00  93317.000000
# std     29.011492                  NaN  17625.345811
#
#        Basic Salary- Color bars  Basic Salary- icon set
# count                100.000000              100.000000
# mean                4889.287000            48892.870000
# min                  890.000000             8900.000000
# 25%                 4033.300000            40333.000000
# 50%                 4959.500000            49595.000000
# 75%                 6176.775000            61767.750000
# max                 9331.700000            93317.000000
# std                 1762.534581            17625.345811

# %%
df.min()
# Out:
# Empcode                                       1
# First Name                               Aakash
# Last Name                                  Baig
# Dept                                      Admin
# Region                                     east
# Branch                                     Agra
# Hiredate                    1977-01-01 00:00:00
# Basic Salary                               8900
# Basic Salary- Color bars                  890.0
# Basic Salary- icon set                     8900
# dtype: object

# %%
df.max()
# Out:
# Empcode                                     100
# First Name                               Zarina
# Last Name                                   Zha
# Dept                                      Sales
# Region                                     west
# Branch                                    delhi
# Hiredate                    1999-12-12 00:00:00
# Basic Salary                              93317
# Basic Salary- Color bars                 9331.7
# Basic Salary- icon set                    93317
# dtype: object

# %%
df.max()
# Out:
# Empcode                                     100
# First Name                               Zarina
# Last Name                                   Zha
# Dept                                      Sales
# Region                                     west
# Branch                                    delhi
# Hiredate                    1999-12-12 00:00:00
# Basic Salary                              93317
# Basic Salary- Color bars                 9331.7
# Basic Salary- icon set                    93317
# dtype: object

# %%
df.std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      84             try:
# ---> 85                 return f(*args, **kwargs)
#      86             except ValueError as e:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanvar(values, axis, skipna, ddof, mask)
#    1012     # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1013     avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1014     if axis is not None:
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      53
#
# ValueError: could not convert string to float: 'Chitra'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3779/3390915376.py in <cell line: 0>()
# ----> 1 df.std()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   11746         **kwargs,
#   11747     ):
# > 11748         result = super().std(axis, skipna, ddof, numeric_only, **kwargs)
#   11749         if isinstance(result, Series):
#   11750             result = result.__finalize__(self, method="std")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12356         **kwargs,
#   12357     ) -> Series | float:
# > 12358         return self._stat_function_ddof(
#   12359             "std", nanops.nanstd, axis, skipna, ddof, numeric_only, **kwargs
#   12360         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   12320             axis = 0
#   12321
# > 12322         return self._reduce(
#   12323             func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   12324         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11560         # After possibly _get_data and transposing, we are now in the
#   11561         #  simple case where we can use BlockManager.reduce
# > 11562         res = df._mgr.reduce(blk_func)
#   11563         out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564         if out_dtype is not None and out.dtype != "boolean":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in reduce(self, func)
#    1498         res_blocks: list[Block] = []
#    1499         for blk in self.blocks:
# -> 1500             nbs = blk.reduce(func)
#    1501             res_blocks.extend(nbs)
#    1502
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in reduce(self, func)
#     402         assert self.ndim == 2
#     403
# --> 404         result = func(self.values)
#     405
#     406         if self.values.ndim == 1:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in blk_func(values, axis)
#   11479                     return np.array([result])
#   11480             else:
# > 11481                 return op(values, axis=axis, skipna=skipna, **kwds)
#   11482
#   11483         def _get_data() -> DataFrame:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     145                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#     149             return result
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanstd(values, axis, skipna, ddof, mask)
#     948     values, mask = _get_values(values, skipna, mask=mask)
#     949
# --> 950     result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof, mask=mask))
#     951     return _wrap_results(result, orig_dtype)
#     952
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      90                 # object arrays that contain strings
#      91                 if is_object_dtype(args[0]):
# ---> 92                     raise TypeError(e) from e
#      93                 raise
#      94
#
# TypeError: could not convert string to float: 'Chitra'

# %%
df.describe()
# Out:
#           Empcode             Hiredate  Basic Salary  \
# count  100.000000                  100    100.000000
# mean    50.500000  1989-12-15 15:21:36  48892.870000
# min      1.000000  1977-01-01 00:00:00   8900.000000
# 25%     25.750000  1987-09-06 12:00:00  40333.000000
# 50%     50.500000  1988-10-29 12:00:00  49595.000000
# 75%     75.250000  1995-03-03 00:00:00  61767.750000
# max    100.000000  1999-12-12 00:00:00  93317.000000
# std     29.011492                  NaN  17625.345811
#
#        Basic Salary- Color bars  Basic Salary- icon set
# count                100.000000              100.000000
# mean                4889.287000            48892.870000
# min                  890.000000             8900.000000
# 25%                 4033.300000            40333.000000
# 50%                 4959.500000            49595.000000
# 75%                 6176.775000            61767.750000
# max                 9331.700000            93317.000000
# std                 1762.534581            17625.345811

# %%
df.mean(df.head(50))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3779/242836564.py in <cell line: 0>()
# ----> 1 df.mean(df.head(50))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11448
#   11449         if axis is not None:
# > 11450             axis = self._get_axis_number(axis)
#   11451
#   11452         def func(values: np.ndarray):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
# --> 576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
#     578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'DataFrame'

# %%
df1=pd.read_excel("/content/Book33.xlsx")

# %%
df1.describe()
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2           Unnamed: 3  Unnamed: 4  \
# count         327        327        327                  327         327
# unique        327        255        166                  320          11
# top         E-326     Rajesh      Kumar  2005-05-16 00:00:00  Operations
# freq            1          7         45                    2          41
#
#        Unnamed: 5 Unnamed: 6  Unnamed: 7      =UPPER(F3)         =LOWER(I3)  \
# count         327        327         327               1                  1
# unique          5         39         323               1                  1
# top          West     Mysore       40895  CAPITAL(Upper)  SMALL CASE(Lower)
# freq          106         17           2               1                  1
#
#                   =PROPER(J3) =CONCATENATE(B3," ",C3)  =B3&" "&C3  \
# count                       1                       1           1
# unique                      1                       1           1
# top     Sentence Case(Proper)      Merge(Concatenate)  Full Name
# freq                        1                       1           1
#
#        =RIGHT(G3,4) =LEFT(G3,2) =MID(G3,3,2) =TRIM(V3) =FIND("with",Q3)  \
# count             1           1            1         1                1
# unique            1           1            1         1                1
# top           Right        Left          Mid      Trim             Find
# freq              1           1            1         1                1
#
#        =REPLACE(V4,1,3,"new_")
# count                        1
# unique                       1
# top                    Replace
# freq                         1

# %%
df1.mean(df1.head(50))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3779/2815026073.py in <cell line: 0>()
# ----> 1 df1.mean(df1.head(50))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11448
#   11449         if axis is not None:
# > 11450             axis = self._get_axis_number(axis)
#   11451
#   11452         def func(values: np.ndarray):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
# --> 576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
#     578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'DataFrame'

# %%
df2=df1.head(20)

# %%
df.columns
# Out:
# Index(['Empcode', 'First Name', 'Last Name', 'Dept', 'Region', 'Branch',
#        'Hiredate', 'Basic Salary', 'Basic Salary- Color bars',
#        'Basic Salary- icon set'],
#       dtype='object')

# %%
df.Dept
# Out:
# 0      Finance
# 1        Sales
# 2        Admin
# 3          CCD
# 4          R&D
#         ...
# 95       Admin
# 96        Mktg
# 97         CCD
# 98       Sales
# 99    Director
# Name: Dept, Length: 100, dtype: object

# %%
df['Dept']
# Out:
# 0      Finance
# 1        Sales
# 2        Admin
# 3          CCD
# 4          R&D
#         ...
# 95       Admin
# 96        Mktg
# 97         CCD
# 98       Sales
# 99    Director
# Name: Dept, Length: 100, dtype: object

# %%
df[['Dept']]
# Out:
#         Dept
# 0    Finance
# 1      Sales
# 2      Admin
# 3        CCD
# 4        R&D
# ..       ...
# 95     Admin
# 96      Mktg
# 97       CCD
# 98     Sales
# 99  Director
#
# [100 rows x 1 columns]

# %%
df['Basic Salary']
# Out:
# 0      8900
# 1      9000
# 2     17487
# 3     17872
# 4     20095
#       ...
# 95    81527
# 96    83428
# 97    84724
# 98    85860
# 99    93317
# Name: Basic Salary, Length: 100, dtype: int64

# %%
df3=df[['Basic Salary']]

# %%
df3.describe()
# Out:
#        Basic Salary
# count    100.000000
# mean   48892.870000
# std    17625.345811
# min     8900.000000
# 25%    40333.000000
# 50%    49595.000000
# 75%    61767.750000
# max    93317.000000

# %%
df3.count()
# Out:
# Basic Salary    100
# dtype: int64

# %%
df3.mean()
# Out:
# Basic Salary    48892.87
# dtype: float64

# %%
df3.min()
# Out:
# Basic Salary    8900
# dtype: int64

# %%
df3.max()
# Out:
# Basic Salary    93317
# dtype: int64

# %%
df4=df.groupby(['Basic Salary'])

# %%
df['Basic Salary']>20000
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: Basic Salary, Length: 100, dtype: bool

# %%
df[df['Basic Salary']>20000]
# Out:
#     Empcode First Name    Last Name      Dept Region     Branch   Hiredate  \
# 4        42      Pooja      Gokhale       R&D   east   Calcutta 1991-09-29
# 5         8      Neena    Mukherjee       R&D  north       Agra 1989-09-04
# 6        80   Dayanand       Gandhi      Mktg  north  Ferozepur 1988-10-30
# 7        18     Aakash        Dixit     Admin   west      Nasik 1983-03-01
# 8        88      Vinit  Shrivastava      Mktg   west       Pune 1997-12-30
# ..      ...        ...          ...       ...    ...        ...        ...
# 95        3    Kuldeep       Sharma     Admin  south   Hydrabad 1999-03-01
# 96       87    Jignesh     Tripathi      Mktg  south   Hydrabad 1998-01-16
# 97       54     Vishal  Virsinghani       CCD   east    Gangtok 1995-03-03
# 98       78       Deep       Chhaya     Sales   west     Mumbai 1988-10-28
# 99       14    Sheetal        Desai  Director  south     cochin 1984-12-12
#
#     Basic Salary  Basic Salary- Color bars  Basic Salary- icon set
# 4          20095                    2009.5                   20095
# 5          20739                    2073.9                   20739
# 6          21207                    2120.7                   21207
# 7          21682                    2168.2                   21682
# 8          22139                    2213.9                   22139
# ..           ...                       ...                     ...
# 95         81527                    8152.7                   81527
# 96         83428                    8342.8                   83428
# 97         84724                    8472.4                   84724
# 98         85860                    8586.0                   85860
# 99         93317                    9331.7                   93317
#
# [96 rows x 10 columns]

# %%
df[['Dept']]
# Out:
#         Dept
# 0    Finance
# 1      Sales
# 2      Admin
# 3        CCD
# 4        R&D
# ..       ...
# 95     Admin
# 96      Mktg
# 97       CCD
# 98     Sales
# 99  Director
#
# [100 rows x 1 columns]

# %%
df4[1:5,2:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3779/100506856.py in <cell line: 0>()
# ----> 1 df4[1:5,2:5]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1945             # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946             # valid syntax, so don't raise
# -> 1947             raise ValueError(
#    1948                 "Cannot subset columns with a tuple with more than one element. "
#    1949                 "Use a list instead."
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.

# %%
df[:,2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(None, None, None), 2)
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipykernel_3779/1244477770.py in <cell line: 0>()
# ----> 1 df[:,2]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3809                 and any(isinstance(x, slice) for x in casted_key)
#    3810             ):
# -> 3811                 raise InvalidIndexError(key)
#    3812             raise KeyError(key) from err
#    3813         except TypeError:
#
# InvalidIndexError: (slice(None, None, None), 2)

# %%
df.Dept
# Out:
# 0      Finance
# 1        Sales
# 2        Admin
# 3          CCD
# 4          R&D
#         ...
# 95       Admin
# 96        Mktg
# 97         CCD
# 98       Sales
# 99    Director
# Name: Dept, Length: 100, dtype: object

# %%
df.iloc[:,:]
# Out:
#     Empcode First Name    Last Name      Dept Region     Branch   Hiredate  \
# 0        38     Chitra     Pednekar   Finance  north    Aligarh 1982-10-01
# 1         1       Raja  Raymondekar     Sales  north  Ferozepur 1977-01-01
# 2        75      Suraj      Saksena     Admin   east   Calcutta 1988-10-25
# 3        81       Tara        Phule       CCD  south    chennai 1988-10-31
# 4        42      Pooja      Gokhale       R&D   east   Calcutta 1991-09-29
# ..      ...        ...          ...       ...    ...        ...        ...
# 95        3    Kuldeep       Sharma     Admin  south   Hydrabad 1999-03-01
# 96       87    Jignesh     Tripathi      Mktg  south   Hydrabad 1998-01-16
# 97       54     Vishal  Virsinghani       CCD   east    Gangtok 1995-03-03
# 98       78       Deep       Chhaya     Sales   west     Mumbai 1988-10-28
# 99       14    Sheetal        Desai  Director  south     cochin 1984-12-12
#
#     Basic Salary  Basic Salary- Color bars  Basic Salary- icon set
# 0           8900                     890.0                    8900
# 1           9000                     900.0                    9000
# 2          17487                    1748.7                   17487
# 3          17872                    1787.2                   17872
# 4          20095                    2009.5                   20095
# ..           ...                       ...                     ...
# 95         81527                    8152.7                   81527
# 96         83428                    8342.8                   83428
# 97         84724                    8472.4                   84724
# 98         85860                    8586.0                   85860
# 99         93317                    9331.7                   93317
#
# [100 rows x 10 columns]

# %%
df.iloc[:,2:6]
# Out:
#       Last Name      Dept Region     Branch
# 0      Pednekar   Finance  north    Aligarh
# 1   Raymondekar     Sales  north  Ferozepur
# 2       Saksena     Admin   east   Calcutta
# 3         Phule       CCD  south    chennai
# 4       Gokhale       R&D   east   Calcutta
# ..          ...       ...    ...        ...
# 95       Sharma     Admin  south   Hydrabad
# 96     Tripathi      Mktg  south   Hydrabad
# 97  Virsinghani       CCD   east    Gangtok
# 98       Chhaya     Sales   west     Mumbai
# 99        Desai  Director  south     cochin
#
# [100 rows x 4 columns]

# %%
df.iloc[1:6,2:7]
# Out:
#      Last Name   Dept Region     Branch   Hiredate
# 1  Raymondekar  Sales  north  Ferozepur 1977-01-01
# 2      Saksena  Admin   east   Calcutta 1988-10-25
# 3        Phule    CCD  south    chennai 1988-10-31
# 4      Gokhale    R&D   east   Calcutta 1991-09-29
# 5    Mukherjee    R&D  north       Agra 1989-09-04

# %%
df.iloc[0:10,1:4]
# Out:
#   First Name    Last Name       Dept
# 0     Chitra     Pednekar    Finance
# 1       Raja  Raymondekar      Sales
# 2      Suraj      Saksena      Admin
# 3       Tara        Phule        CCD
# 4      Pooja      Gokhale        R&D
# 5      Neena    Mukherjee        R&D
# 6   Dayanand       Gandhi       Mktg
# 7     Aakash        Dixit      Admin
# 8      Vinit  Shrivastava       Mktg
# 9    K. Sita    Narayanan  Personnel

# %%
df.iloc[:,[5,6]]
# Out:
#        Branch   Hiredate
# 0     Aligarh 1982-10-01
# 1   Ferozepur 1977-01-01
# 2    Calcutta 1988-10-25
# 3     chennai 1988-10-31
# 4    Calcutta 1991-09-29
# ..        ...        ...
# 95   Hydrabad 1999-03-01
# 96   Hydrabad 1998-01-16
# 97    Gangtok 1995-03-03
# 98     Mumbai 1988-10-28
# 99     cochin 1984-12-12
#
# [100 rows x 2 columns]

# %%
df.iloc[[60]]
# Out:
#     Empcode First Name Last Name Dept Region    Branch   Hiredate  \
# 60       84      Pinky    Robert  R&D   east  Calcutta 1999-03-03
#
#     Basic Salary  Basic Salary- Color bars  Basic Salary- icon set
# 60         54124                    5412.4                   54124

# %%
df.iloc[[0,2]]
# Out:
#    Empcode First Name Last Name     Dept Region    Branch   Hiredate  \
# 0       38     Chitra  Pednekar  Finance  north   Aligarh 1982-10-01
# 2       75      Suraj   Saksena    Admin   east  Calcutta 1988-10-25
#
#    Basic Salary  Basic Salary- Color bars  Basic Salary- icon set
# 0          8900                     890.0                    8900
# 2         17487                    1748.7                   17487

# %%
df[['Basic Salary']].agg(['min','max','mean'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2040/4277297692.py in <cell line: 0>()
# ----> 1 df[['Basic Salary']].agg(['min','max','mean'])
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/Excel sal data.xlsx')

# %%
df[['Basic Salary','Empcode']].agg(['min','max','mean'])
# Out:
#       Basic Salary  Empcode
# min        8900.00      1.0
# max       93317.00    100.0
# mean      48892.87     50.5

# %%
df[['Basic Salary']].mean()
# Out:
# Basic Salary    48892.87
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=[-3,5,7]
y=[10,2,5]

# %%
fig=plt.figure(figsize=(15,3))

# %%
plt.plot(x,y)
plt.xlim(0,10)
plt.ylim(-3,8)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Plot')
plt.suptitle('Sales comparison',size=20,y=1.03)
# Out:
# Text(0.5, 1.03, 'Sales comparison')

# %%
a=plt.subplots(2,4)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from scipy import stats
import pandas as pd
import seaborn as sns
import numpy as np

# %%
 Beml=pd.read_excel("/content/BEML_data.xlsx")

# %%
Glaxo=pd.read_excel("/content/GLAXO_data.xlsx")

# %%
Glaxo_ci=stats.
